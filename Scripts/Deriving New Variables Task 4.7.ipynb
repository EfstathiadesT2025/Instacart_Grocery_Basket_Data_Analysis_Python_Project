# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
# Python shortcut - reusable path
path = r'C:\Users\thoma\OneDrive\Dokumente\data analytics\Data Project 4\06-2025 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\thoma\\OneDrive\\Dokumente\\data analytics\\Data Project 4\\06-2025 Instacart Basket Analysis'

# %%
# Importing 'ords_prods_merge'
df_ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data','Prepared Data', 'ords_prods_merge.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (30356999, 15)

# %%
df_ords_prods_merge_1M = df_ords_prods_merge[:1000000]

# %%
df_ords_prods_merge_1M.shape
# Out:
# (1000000, 15)

# %%
# Question 1. - new column 'busiest_day'
# Assigning the string values
result = []

for value in df_ords_prods_merge_1M["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
# ...

# %%
# Creating the new column within the dataframe and merging it with the result values
df_ords_prods_merge_1M['busiest_day'] = result
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_5684\584212822.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_merge_1M['busiest_day'] = result

# %%
# Frequency check
df_ords_prods_merge_1M['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    696453
# Busiest day       183358
# Least busy        120189
# Name: count, dtype: int64

# %%
# Question 2. - new column 'Busiest days'
# Renaming
df_ords_prods_merge_1M.rename(columns = {'busiest_day' : 'Busiest days'}, inplace = True)
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_5684\412683540.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_merge_1M.rename(columns = {'busiest_day' : 'Busiest days'}, inplace = True)

# %%
# Frequency check
df_ords_prods_merge_1M["order_dow"].value_counts(dropna = False)
# Out:
# order_dow
# 0.0    183358
# 1.0    174411
# 6.0    136666
# 5.0    132450
# 2.0    131994
# 3.0    120932
# 4.0    120189
# Name: count, dtype: int64

# %%
# Assigning the string values
result = []

for value in df_ords_prods_merge_1M["order_dow"]:
  if value in (0, 1):
    result.append("Two busiest days")
  elif value in (3, 4):
    result.append("Two slowest days")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Two busiest days',
#  'Two slowest days',
#  'Two busiest days',
#  'Regularly busy',
#  'Two slowest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two slowest days',
#  'Two slowest days',
#  'Regularly busy',
#  'Two slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Two busiest days',
#  'Two busiest days',
#  'Regularly busy',
#  'Two busiest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two slowest days',
#  'Regularly busy',
#  'Two busiest days',
#  'Two busiest days',
#  'Regularly busy',
#  'Two slowest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two slowest days',
#  'Two busiest days',
#  'Two busiest days',
#  'Two slowest days',
#  'Regularly busy',
#  'Two busiest days',
#  'Two busiest days',
# ...

# %%
# Creating the new column and merging it with the result values
df_ords_prods_merge_1M["Busiest days"] = result
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_5684\3893200202.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_merge_1M["Busiest days"] = result

# %%
# Frequency check
df_ords_prods_merge_1M["Busiest days"].value_counts(dropna = False)
# Out:
# Busiest days
# Regularly busy      401110
# Two busiest days    357769
# Two slowest days    241121
# Name: count, dtype: int64

# %%
# Question 3. - accuracy check
df_ords_prods_merge_1M["Busiest days"].describe()
# Out:
# count            1000000
# unique                 3
# top       Regularly busy
# freq              401110
# Name: Busiest days, dtype: object

# %% [markdown]
# # As a result there's:
# # - 3 unique string values
# # - On top is the 'Regularly busy' value with a count of 400728

# %%
# Question 4. - new column 'busiest_period_of_day'
# Frequency check of 'order_hour_of_day'
df_ords_prods_merge_1M["order_hour_of_day"].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10.0    86554
# 11.0    84832
# 14.0    83233
# 13.0    82124
# 15.0    81162
# 12.0    80226
# 16.0    77449
# 9.0     77359
# 17.0    63946
# 8.0     53964
# 18.0    49711
# 19.0    38333
# 20.0    30142
# 7.0     27922
# 21.0    24333
# 22.0    19069
# 23.0    12092
# 6.0      9173
# 0.0      6527
# 1.0      3561
# 5.0      2872
# 2.0      2156
# 3.0      1644
# 4.0      1616
# Name: count, dtype: int64

# %%
# Assigning the new string values
result2 = []

for value in df_ords_prods_merge_1M["order_hour_of_day"]:
  if value in (10, 11, 14, 15, 13, 12, 16, 9):
    result2.append("Most orders")
  elif value in (3, 4, 2, 5, 1, 0, 6, 23):
    result2.append("Fewest orders")
  else:
    result2.append("Average orders")

# %%
result2
# Out:
# ['Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# Creating the new column within the dataframe and merging it with the result2 values
df_ords_prods_merge_1M["busiest_period_of_day"] = result2
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_5684\3635616622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_merge_1M["busiest_period_of_day"] = result2

# %%
# Question 5. - frequency check
df_ords_prods_merge_1M["busiest_period_of_day"].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       652939
# Average orders    307420
# Fewest orders      39641
# Name: count, dtype: int64

# %%
# Question 7. - exporting the dataframe
df_ords_prods_merge_1M.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'Pr_ords_prods_merge_1M_new_var.pkl'))
